# %% [markdown]
# # Contents
#
# 01. Importing libraries
# 02. Importing data
# 03. Task 4.8
# 04. Exporting data

# %% [markdown]
# ### 01. Importing libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ### 02. Importing data

# %%
# Import main folder
path = r'C:\Users\amwil\OneDrive\Career Foundry Project Work\05-2020 Instacart Basket Analysis'

# %%
# Import ords_prods_merged.pkl
df_ords_prods_merged = pd.read_pickle(os.path.join(path,'02 Data', 'Prepared Data', 'ords_prods_merged.pkl'))

# %% [markdown]
# ### 03. Task 4.8

# %%
# Create a loyalty flag 
df_ords_prods_merged['median_days_since_prior_order'] = df_ords_prods_merged.groupby(['user_id'])['days_since_prior_order'].transform(np.median)

# %%
# Check the result
df_ords_prods_merged.head(15)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_time  \
# 0    2539329        1             1                   2           8
# 1    2398795        1             2                   3           7
# 2     473747        1             3                   3          12
# 3    2254736        1             4                   4           7
# 4     431534        1             5                   4          15
# 5    3367565        1             6                   2           7
# 6     550135        1             7                   1           9
# 7    3108588        1             8                   1          14
# 8    2295261        1             9                   1          16
# 9    2550362        1            10                   4           8
# 10   2968173       15            15                   1           9
# 11   1870022       15            17                   2          16
# 12   1911383       15            18                   2          11
# ...

# %%
# Assign a value of Non frequent customer as order frequency flag
df_ords_prods_merged.loc[df_ords_prods_merged['median_days_since_prior_order'] > 20, 'order_frequency_flag'] = 'Non frequent customer'

# %%
# Assign a value of Regular customer as an order frequency flag
df_ords_prods_merged.loc[(df_ords_prods_merged['median_days_since_prior_order'] > 10) & (df_ords_prods_merged['median_days_since_prior_order'] <= 20), 'order_frequency_flag'] = 'Regular customer'

# %%
# Assign a value of Frequent customer as an order frequency flag
df_ords_prods_merged.loc[df_ords_prods_merged['median_days_since_prior_order'] <= 10, 'order_frequency_flag'] = 'Frequent customer'

# %%
# Print frequency of order frequency flag
df_ords_prods_merged['order_frequency_flag'].value_counts(dropna = False)
# Out:
# Frequent customer        22790523
# Regular customer          6927608
# Non frequent customer     2686728
# Name: order_frequency_flag, dtype: int64

# %%
# Check code
df_ords_prods_merged[['user_id', 'order_frequency_flag', 'days_since_prior_order']].head(15)
# Out:
#     user_id order_frequency_flag  days_since_prior_order
# 0         1     Regular customer                     7.0
# 1         1     Regular customer                    15.0
# 2         1     Regular customer                    21.0
# 3         1     Regular customer                    29.0
# 4         1     Regular customer                    28.0
# 5         1     Regular customer                    19.0
# 6         1     Regular customer                    20.0
# 7         1     Regular customer                    14.0
# 8         1     Regular customer                     0.0
# 9         1     Regular customer                    30.0
# 10       15    Frequent customer                     7.0
# 11       15    Frequent customer                     8.0
# 12       15    Frequent customer                     7.0
# 13       15    Frequent customer                     7.0
# 14       15    Frequent customer                    14.0

# %% [markdown]
# ### 04. Exporting data

# %%
# Export data
df_ords_prods_merged.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_merged.pkl'))
