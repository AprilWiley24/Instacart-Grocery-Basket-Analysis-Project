# %% [markdown]
# #Contents
#
# 01. Importing libraries
# 02. Importing data
# 03. Data Quality Check
# 04. Exporting data

# %% [markdown]
# #01. Importing libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# #02. Importing data

# %%
# Import main folder
path = r'C:\Users\amwil\OneDrive\Career Foundry Project Work\05-2020 Instacart Basket Analysis'

# %%
# Import ords_prods_merged.pkl
df_ords_prods_merged = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_merged.pkl'))

# %% [markdown]
# #03. Data Quality Check

# %%
# Check beginning of dataframe
df_ords_prods_merged.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_time  \
# 0   2539329        1             1                   2           8
# 1   2398795        1             2                   3           7
# 2    473747        1             3                   3          12
# 3   2254736        1             4                   4           7
# 4    431534        1             5                   4          15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                     7.0         196                  1          0   both
# 1                    15.0         196                  1          1   both
# 2                    21.0         196                  1          1   both
# 3                    29.0         196                  1          1   both
# 4                    28.0         196                  1          1   both
#
#    ...    price_range_loc     busiest day    busiest days  \
# ...

# %%
# Drop add_to_cart_order
df_ords_prods_merged = df_ords_prods_merged.drop(columns = ['order_id', 'add_to_cart_order', 'reordered', '_merge', 'aisle_id', 'price_range_loc', 'busiest days'])

# %%
# Check beginning of dataframe
df_ords_prods_merged.head()
# Out:
#    user_id  order_number  orders_day_of_week  order_time  \
# 0        1             1                   2           8
# 1        1             2                   3           7
# 2        1             3                   3          12
# 3        1             4                   4           7
# 4        1             5                   4          15
#
#    days_since_prior_order  product_id product_name  department_id  prices  \
# 0                     7.0         196         Soda              7     9.0
# 1                    15.0         196         Soda              7     9.0
# 2                    21.0         196         Soda              7     9.0
# 3                    29.0         196         Soda              7     9.0
# 4                    28.0         196         Soda              7     9.0
#
#       busiest day busiest_period_of_day  max_order  loyalty_flag  \
# 0  Regularly busy        Average orders         10  New customer
# ...

# %% [markdown]
# #04. Exporting data

# %%
# Export ords_prods_merged_1.pkl
df_ords_prods_merged.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_merged_1.pkl'))
